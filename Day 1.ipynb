# %%
# Input and Output Functions

# %%
# Output Function
print(33)
# Out:
# 33

# %%
# Variables
a = 3
b = 4
c = 5

# %%
a + b
# Out:
# 7

# %%
first_name = 'Ram'
last_name = 'Bahadur'

# %%
first_name + last_name
# Out:
# 'RamBahadur'

# %% [markdown]
# # Data Types

# %%
'''
    Integer -> Number Data (Whole Numbers) (int)
    String -> Alphabets, Numbers, Special Characters (str)
    Float -> Decimal Numbers (1.2, 4.5, 6.777789999)
    Boolean -> True (1) and False (0) (bool)
    None -> Used for future upcoming values
    Complex -> a + 3j
'''
# Out:
# '\n    Integer -> Number Data (Whole Numbers) (int)\n    String -> Alphabets, Numbers, Special Characters (str)\n    Float -> Decimal Numbers (1.2, 4.5, 6.777789999)\n    Boolean -> True (1) and False (0) (bool)\n    None -> Used for future upcoming values\n    Complex -> a + 3j\n'

# %%
# value = 3.44556678

# %%
# single Line Comment (#) 
# and Multi Line Comment (''' ''')

# %% [markdown]
# # Input Function

# %%
# Calculate sum of two numbers
a = 3
b = 4
# Add Operation
sum = a + b
print(sum)
# Out:
# 7

# %%
# Calculate sum of two numbers
a = float(input("Enter first number: "))
b = int(input("Enter second number: "))
# Add Operation
sum = a + b
print(sum)
# Out:
# Enter first number:  3
# Enter second number:  3
# 6.0

# %%
# Integer -> Whole Number (It does not accept Decimal Number)
# Float -> It accepts both Decimal and Whole number (converts it into decimal number)

# %%
c = 1

# %%
type(c)
# Out:
# int

# %%
float(c)
# Out:
# 1.0

# %%
# Calculate sum of two numbers
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
# Add Operation
sum = a + b
print("Sum of first number: 2 and second number: 2 is:",sum) # Sum of two numbers is: output
# Out:
# Enter first number:  3
# Enter second number:  3
# Sum of first number: 2 and second number: 2 is: 6

# %% [markdown]
# # f-string (Format String)

# %%
print(f"Sum of first number {a} and second number {b} numbers is: {sum}")
# Out:
# Sum of first number 3 and second number 3 numbers is: 6

# %% [markdown]
# # Operators

# %%
'''
    Arithmetic Operator
        +, -, *, /, %(Reminder/modulus), // (float division), ** (power)
        
    Logical Operator
        And, Or, Not
    
    Comparision Operator
        >, <, >=, <=, =, ==, !=
'''
# Out:
# '\n    Arithmetic Operator\n        +, -, *, /, %(Reminder/modulus), // (float division), ** (power)\n        \n    Logical Operator\n        And, Or, Not\n    \n    Comparision Operator\n        >, <, >=, <=, =, ==, !=\n'

# %%
a = 3
b = 3

# %%
3<=3
# Out:
# True

# %%
# Double equals compares value
b == a
# Out:
# True

# %%
# (variable)  (Operator)   (Operand/Value)
a = 3

# %%
# Calculate sum of two numbers
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
# power
output = a ** b
print(output)
# Out:
# Enter first number:  2
# Enter second number:  6
# 64

# %%
# We have to use logical operator with comparision operator

# %%
marks1 = 50
marks2 = 30

print(marks1 < 40)
print(marks2 < 40)
# Out:
# False
# True

# %%
# True    # False
marks1 > 40 or marks2 > 40
# Out:
# True

# %%
marks1 != 40
# Out:
# True

# %% [markdown]
# # Variables

# %% [markdown]
# ## Camel Case

# %%
firstNumberIs = 1
secondNumberIs = 2

# %% [markdown]
# ## Snake Case

# %%
first_number_is = 3
second_number_is = 4
